# %% [markdown]
# <a href="https://colab.research.google.com/github/KuldeepIsharwal/Machine-Learning-Basics/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/breast-cancer.csv')

# %%
df.sample(5)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 215   8810987         M        13.86         16.93           90.96      578.9
# 4    84358402         M        20.29         14.34          135.10     1297.0
# 324  89511501         B        12.20         15.21           78.01      457.9
# 396  90401601         B        13.51         18.89           88.10      558.1
# 365    901088         M        20.44         21.78          133.80     1293.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 215          0.10260           0.15170         0.09901              0.05602
# 4            0.10030           0.13280         0.19800              0.10430
# 324          0.08673           0.06545         0.01994              0.01692
# 396          0.10590           0.11470         0.08580              0.05381
# 365          0.09150           0.11310         0.09799              0.07785
#
# ...

# %%
df = df.drop(columns=['id','Unnamed: 32'])

# %%
df.sample(5)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 567         M        20.60         29.33          140.10     1265.0
# 490         B        12.25         22.44           78.18      466.5
# 255         M        13.96         17.05           91.43      602.4
# 298         B        14.26         18.17           91.22      633.1
# 492         M        18.01         20.56          118.40     1007.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 567          0.11780            0.2770         0.35140              0.15200
# 490          0.08192            0.0520         0.01714              0.01261
# 255          0.10960            0.1279         0.09789              0.05246
# 298          0.06576            0.0522         0.02475              0.01374
# 492          0.10010            0.1289         0.11700              0.07762
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df.drop(columns=['diagnosis']),df['diagnosis'],test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.46649743, -0.13728933, -0.44421138, ..., -0.19435087,
#          0.17275669,  0.20372995],
#        [ 1.36536344,  0.49866473,  1.30551088, ...,  0.99177862,
#         -0.561211  , -1.00838949],
#        [ 0.38006578,  0.06921974,  0.40410139, ...,  0.57035018,
#         -0.10783139, -0.20629287],
#        ...,
#        [-0.73547237, -0.99852603, -0.74138839, ..., -0.27741059,
#         -0.3820785 , -0.32408328],
#        [ 0.02898271,  2.0334026 ,  0.0274851 , ..., -0.49027026,
#         -1.60905688, -0.33137507],
#        [ 1.87216885,  2.80077153,  1.80354992, ...,  0.7925579 ,
#         -0.05868885, -0.09467243]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred = knn.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9473684210526315
