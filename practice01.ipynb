# %% [markdown]
# <a href="https://colab.research.google.com/github/KuldeepIsharwal/Machine-Learning-Basics/blob/main/practice01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df.describe()

# %%
df = pd.read_csv('/content/Housing.csv')
df.sample(7)

# %% [markdown]
# i took basic understading og data till here

# %%
df.info()

# %% [markdown]
# by looking at df.info() i think that we can change datatype of price bedrooms bathrooms sotries and parking to int32 instead of int 64.

# %%
df.isnull().sum()

# %% [markdown]
# BTW it is a good thing tahat our data does not have any missing values

# %% [markdown]
# i will start univariate analysis of columns now

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='mainroad', data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='guestroom', data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='basement', data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='hotwaterheating', data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='airconditioning', data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='furnishingstatus', data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='prefarea', data=df)

# %%
sns.boxplot(df['price'])

# %% [markdown]
# by looking at boxplot of prices ik that we are dealing with premium houses tooo

# %%
sns.scatterplot(data = df, y='price', x='area',hue='mainroad')

# %% [markdown]
# by looking at scatterplot i can infer that same area but having prefarea increases prices relative to other houses with same area
# it is a small observation but there are some outliars too

# %%
sns.barplot(x='bedrooms' ,y = 'price',data=df,hue='bathrooms')

# %% [markdown]
# iknew that with bedrooms price will increase but whan we also add factor of bathrooms we see that it makes a lot of difference of how many no. of bathrooms u have over number of bedrooms
# i think i should replace bathrooms with bedrooms/bathrooms

# %%
sns.heatmap(pd.crosstab(df['guestroom'], df['bedrooms']))

# %% [markdown]
# ```
# i tried to eleminate colns by doing univariate and multivariate analysis but i think my analysis is not that good so i will use the last optn and depending upon that i will present my views about this data```

# %%
# !pip install ydata_profiling
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="My Automated EDA Report", explorative=True)

profile.to_file("eda_report.html")

# %% [markdown]
# area is highly overall correlated with price(iknew this frommy analasis too)
# if i had to remove features to make this simple i would remove ac,bathroom,bedrrom,furnishingstats,basement cz they all have strong corr with price and area also have the same so area can represent them or i can make another variablr out of them by combiniing them somehow
# and now i think i can entirely remove hotwaterheating cz it has strong corr with noone and also most of the houses dont even have it
# and i think same about no of stories the house have cz if a house has multiple stories likely is that it has lots of area so i will remove this completely and wont consider any part of it
# prefarea and price have med corr and so does prefarea and area so i will remove this too
#
# that is all my obervation and my eda report
